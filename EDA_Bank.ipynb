# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
bank_df=pd.read_csv(r"C:\Users\Almannan\OneDrive\NareshIT\DSAIML\DataFiles\bank.csv", usecols=[0], header=None)
bank_df
# Out:
#                                                       0
# 0     age;"job";"marital";"education";"default";"bal...
# 1     30;"unemployed";"married";"primary";"no";1787;...
# 2     33;"services";"married";"secondary";"no";4789;...
# 3     35;"management";"single";"tertiary";"no";1350;...
# 4     30;"management";"married";"tertiary";"no";1476...
# ...                                                 ...
# 4517  33;"services";"married";"secondary";"no";-333;...
# 4518  57;"self-employed";"married";"tertiary";"yes";...
# 4519  57;"technician";"married";"secondary";"no";295...
# 4520  28;"blue-collar";"married";"secondary";"no";11...
# 4521  44;"entrepreneur";"single";"tertiary";"no";113...
#
# [4522 rows x 1 columns]

# %%
bank_df=pd.read_csv(r"C:\Users\Almannan\OneDrive\NareshIT\DSAIML\DataFiles\bank.csv")
bank_df
# Out:
#      age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"
# 0     30;"unemployed";"married";"primary";"no";1787;...
# 1     33;"services";"married";"secondary";"no";4789;...
# 2     35;"management";"single";"tertiary";"no";1350;...
# 3     30;"management";"married";"tertiary";"no";1476...
# 4     59;"blue-collar";"married";"secondary";"no";0;...
# ...                                                 ...
# 4516  33;"services";"married";"secondary";"no";-333;...
# 4517  57;"self-employed";"married";"tertiary";"yes";...
# 4518  57;"technician";"married";"secondary";"no";295...
# 4519  28;"blue-collar";"married";"secondary";"no";11...
# 4520  44;"entrepreneur";"single";"tertiary";"no";113...
#
# [4521 rows x 1 columns]

# %%
bank_df = pd.read_csv(r"C:\Users\Almannan\OneDrive\NareshIT\DSAIML\DataFiles\bank.csv", header=None, names=[''])  # Assuming there's no header, specify column name

# Split the single column into multiple columns based on delimiter
bank_df = df['Column'].str.split(';', expand=True)
bank_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Column'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 4
# ...

# %%
df = pd.read_csv(r"C:\Users\Almannan\OneDrive\NareshIT\DSAIML\DataFiles\bank.csv", header=None, names=['Column'])  # Assuming there's no header, specify column name

# Split the single column into multiple columns based on delimiter
df = df['Column'].str.split(';', expand=True)
df
# Out:
#        0                1          2            3          4          5   \
# 0     age            "job"  "marital"  "education"  "default"  "balance"
# 1      30     "unemployed"  "married"    "primary"       "no"       1787
# 2      33       "services"  "married"  "secondary"       "no"       4789
# 3      35     "management"   "single"   "tertiary"       "no"       1350
# 4      30     "management"  "married"   "tertiary"       "no"       1476
# ...   ...              ...        ...          ...        ...        ...
# 4517   33       "services"  "married"  "secondary"       "no"       -333
# 4518   57  "self-employed"  "married"   "tertiary"      "yes"      -3313
# 4519   57     "technician"  "married"  "secondary"       "no"        295
# 4520   28    "blue-collar"  "married"  "secondary"       "no"       1137
# 4521   44   "entrepreneur"   "single"   "tertiary"       "no"       1136
#
#              6       7           8      9        10          11          12  \
# ...

# %%
bank_df = pd.read_csv(r"C:\Users\Almannan\OneDrive\NareshIT\DSAIML\DataFiles\bank.csv", header=None, names=['Column'])  # Assuming there's no header, specify column name

# Split the single column into multiple columns based on delimiter
bank_df = bank_df['Column'].str.split(';', expand=True)
bank_df
# Out:
#        0                1          2            3          4          5   \
# 0     age            "job"  "marital"  "education"  "default"  "balance"
# 1      30     "unemployed"  "married"    "primary"       "no"       1787
# 2      33       "services"  "married"  "secondary"       "no"       4789
# 3      35     "management"   "single"   "tertiary"       "no"       1350
# 4      30     "management"  "married"   "tertiary"       "no"       1476
# ...   ...              ...        ...          ...        ...        ...
# 4517   33       "services"  "married"  "secondary"       "no"       -333
# 4518   57  "self-employed"  "married"   "tertiary"      "yes"      -3313
# 4519   57     "technician"  "married"  "secondary"       "no"        295
# 4520   28    "blue-collar"  "married"  "secondary"       "no"       1137
# 4521   44   "entrepreneur"   "single"   "tertiary"       "no"       1136
#
#              6       7           8      9        10          11          12  \
# ...

# %%
bank_df = pd.read_csv(r"C:\Users\Almannan\OneDrive\NareshIT\DSAIML\DataFiles\bank-additional.csv", header=None, names=['Column'])  # Assuming there's no header, specify column name

# Split the single column into multiple columns based on delimiter
bank_df = bank_df['Column'].str.split(';', expand=True)
bank_df
# Out:
#        0              1          2              3          4          5   \
# 0     age          "job"  "marital"    "education"  "default"  "housing"
# 1      30  "blue-collar"  "married"     "basic.9y"       "no"      "yes"
# 2      39     "services"   "single"  "high.school"       "no"       "no"
# 3      25     "services"  "married"  "high.school"       "no"      "yes"
# 4      38     "services"  "married"     "basic.9y"       "no"  "unknown"
# ...   ...            ...        ...            ...        ...        ...
# 4115   30       "admin."  "married"     "basic.6y"       "no"      "yes"
# 4116   39       "admin."  "married"  "high.school"       "no"      "yes"
# 4117   27      "student"   "single"  "high.school"       "no"       "no"
# 4118   58       "admin."  "married"  "high.school"       "no"       "no"
# 4119   34   "management"   "single"  "high.school"       "no"      "yes"
#
#              6            7        8              9   ...          11  \
# ...

# %%
bank_df = pd.read_csv(r"C:\Users\Almannan\OneDrive\NareshIT\DSAIML\DataFiles\bank-additional.csv", sep=';')  # Assuming there's no header, specify column name

# Split the single column into multiple columns based on delimiter

bank_df
# Out:
#       age          job  marital          education default  housing     loan  \
# 0      30  blue-collar  married           basic.9y      no      yes       no
# 1      39     services   single        high.school      no       no       no
# 2      25     services  married        high.school      no      yes       no
# 3      38     services  married           basic.9y      no  unknown  unknown
# 4      47       admin.  married  university.degree      no      yes       no
# ...   ...          ...      ...                ...     ...      ...      ...
# 4114   30       admin.  married           basic.6y      no      yes      yes
# 4115   39       admin.  married        high.school      no      yes       no
# 4116   27      student   single        high.school      no       no       no
# 4117   58       admin.  married        high.school      no       no       no
# 4118   34   management   single        high.school      no      yes       no
#
# ...

# %%
loan_df=pd.read_csv(r"C:\Users\Almannan\OneDrive\NareshIT\DSAIML\DataFiles\loanEligibility_Train.csv", sep=",")
loan_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
loan_df=pd.read_csv(r"C:\Users\Almannan\OneDrive\NareshIT\DSAIML\DataFiles\loanEligibility_Train.csv")
loan_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...
