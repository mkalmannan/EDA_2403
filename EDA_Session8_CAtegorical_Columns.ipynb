# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visa_df=pd.read_csv(r"C:\Users\Almannan\OneDrive\NareshIT\DSAIML\DataFiles\Visadataset.csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cols=visa_df.select_dtypes(include='object').columns
for i in cols:

# %%
for i in cols:
    labels=list(visa_df[i].unique())
    values=[i for i in range(len(labels))]
    d=dict(zip(labels,values))
    visa_df[i]=visa_df[i].map(d)

visa_df
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0            0          0                      0                   0
# 1            1          0                      1                   1
# 2            2          0                      2                   0
# 3            3          0                      2                   0
# 4            4          1                      1                   1
# ...        ...        ...                    ...                 ...
# 25475    25475          0                      2                   1
# 25476    25476          0                      0                   1
# 25477    25477          0                      1                   1
# 25478    25478          0                      1                   1
# 25479    25479          0                      2                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                          0            14513         2007
# ...

# %% [markdown]
# ****

# %% [markdown]
# ***label Encoder***
#
# - Label Encoder is a package under in sickit learn
# -
# - Sickit-learn

# %% [markdown]
# 3 steps
#
#
# - read the package
#
# - save the package
#
# - apply Fit Transform

# %%
# Step 1 - read the package
from sklearn.preprocessing import LabelEncoder
# Step 2 - save the package
le=LabelEncoder()

#step 3 - Apply Fit Tansform

visa_df['case_status']=le.fit_transform(visa_df['case_status'])
visa_df
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0            0          0                      0                   0
# 1            1          0                      1                   1
# 2            2          0                      2                   0
# 3            3          0                      2                   0
# 4            4          1                      1                   1
# ...        ...        ...                    ...                 ...
# 25475    25475          0                      2                   1
# 25476    25476          0                      0                   1
# 25477    25477          0                      1                   1
# 25478    25478          0                      1                   1
# 25479    25479          0                      2                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                          0            14513         2007
# ...

# %%
from sklearn.preprocessing import LabelEncoder
# Step 2 - save the package
le=LabelEncoder()
visa_df['continent']=le.fit_transform(visa_df['continent'])
visa_df
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0            0          0                      0                   0
# 1            1          0                      1                   1
# 2            2          0                      2                   0
# 3            3          0                      2                   0
# 4            4          1                      1                   1
# ...        ...        ...                    ...                 ...
# 25475    25475          0                      2                   1
# 25476    25476          0                      0                   1
# 25477    25477          0                      1                   1
# 25478    25478          0                      1                   1
# 25479    25479          0                      2                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                          0            14513         2007
# ...

# %%
for i in cols:
    labels=list(visa_df[i].unique())
    values=[i for i in range(len(labels))]
    d=dict(zip(labels,values))
    visa_df[i]=visa_df[i].map(d)

visa_df
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0            0          0                      0                   0
# 1            1          0                      1                   1
# 2            2          0                      2                   0
# 3            3          0                      2                   0
# 4            4          1                      1                   1
# ...        ...        ...                    ...                 ...
# 25475    25475          0                      2                   1
# 25476    25476          0                      0                   1
# 25477    25477          0                      1                   1
# 25478    25478          0                      1                   1
# 25479    25479          0                      2                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                          0            14513         2007
# ...

# %%
from sklearn.preprocessing import LabelEncoder
# Step 2 - save the package
le=LabelEncoder()
visa_df['yr_of_estab']=le.fit_transform(visa_df['yr_of_estab'])
visa_df
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0            0          0                      0                   0
# 1            1          0                      1                   1
# 2            2          0                      2                   0
# 3            3          0                      2                   0
# 4            4          1                      1                   1
# ...        ...        ...                    ...                 ...
# 25475    25475          0                      2                   1
# 25476    25476          0                      0                   1
# 25477    25477          0                      1                   1
# 25478    25478          0                      1                   1
# 25479    25479          0                      2                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                          0            14513          189
# ...

# %%
for i in cols:
    labels=list(visa_df[i].unique())
    values=[i for i in range(len(labels))]
    d=dict(zip(labels,values))
    visa_df[i]=visa_df[i].map(d)

visa_df
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0            0          0                      0                   0
# 1            1          0                      1                   1
# 2            2          0                      2                   0
# 3            3          0                      2                   0
# 4            4          1                      1                   1
# ...        ...        ...                    ...                 ...
# 25475    25475          0                      2                   1
# 25476    25476          0                      0                   1
# 25477    25477          0                      1                   1
# 25478    25478          0                      1                   1
# 25479    25479          0                      2                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                          0            14513          189
# ...

# %%
visa_df=pd.read_csv(r"C:\Users\Almannan\OneDrive\NareshIT\DSAIML\DataFiles\Visadataset.csv")
visa_df

from sklearn.preprocessing import LabelEncoder
# Step 2 - save the package
le=LabelEncoder()

for i in cols:
    visa_df[i]=le.fit_transform(visa_df[i])
    
visa_df
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0            0          1                      2                   0
# 1            1          1                      3                   1
# 2            2          1                      0                   0
# 3            3          1                      0                   0
# 4            4          0                      3                   1
# ...        ...        ...                    ...                 ...
# 25475    17204          1                      0                   1
# 25476    17205          1                      2                   1
# 25477    17206          1                      3                   1
# 25478    17207          1                      3                   1
# 25479    17209          1                      0                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                          0            14513         2007
# ...

# %%
visa_df=pd.read_csv(r"C:\Users\Almannan\OneDrive\NareshIT\DSAIML\DataFiles\Visadataset.csv")
visa_df

from sklearn.preprocessing import LabelEncoder
# Step 2 - save the package
le=LabelEncoder()

for i in cols:
    visa_df[i]=le.inverse_transform(visa_df[i],)
    
visa_df
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[20], line 9
#       6 le=LabelEncoder()
#       8 for i in cols:
# ----> 9     visa_df[i]=le.inverse_transform(visa_df[i])
#      11 visa_df
#
# File ~\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:154, in LabelEncoder.inverse_transform(self, y)
#     141 def inverse_transform(self, y):
#     142     """Transform labels back to original encoding.
#     143
#     144     Parameters
#    (...)
#     152         Original encoding.
#     153     """
# --> 154     check_is_fitted(self)
#     155     y = column_or_1d(y, warn=True)
#     156     # inverse transform of empty array is empty array
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1390, in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1385     fitted = [
# ...

# %%
visa_df=pd.read_csv(r"C:\Users\Almannan\OneDrive\NareshIT\DSAIML\DataFiles\Visadataset.csv")


from sklearn.preprocessing import LabelEncoder
# Step 2 - save the package
le=LabelEncoder()
visa_df['education_of_employee']=le.fit_transform(visa_df['education_of_employee'])
visa_df

le.inverse_transform(visa_df['education_of_employee'])
# Out:
# array(['High School', "Master's", "Bachelor's", ..., "Master's",
#        "Master's", "Bachelor's"], dtype=object)

# %%
visa_df=pd.read_csv(r"C:\Users\Almannan\OneDrive\NareshIT\DSAIML\DataFiles\Visadataset.csv")
visa_df

from sklearn.preprocessing import LabelEncoder
# Step 2 - save the package
le=LabelEncoder()

for i in cols:
    visa_df[i]=le.fit_transform(visa_df[i])


visa_df
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0            0          1                      2                   0
# 1            1          1                      3                   1
# 2            2          1                      0                   0
# 3            3          1                      0                   0
# 4            4          0                      3                   1
# ...        ...        ...                    ...                 ...
# 25475    17204          1                      0                   1
# 25476    17205          1                      2                   1
# 25477    17206          1                      3                   1
# 25478    17207          1                      3                   1
# 25479    17209          1                      0                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                          0            14513         2007
# ...

# %%
       
       
visa_df=pd.read_csv(r"C:\Users\Almannan\OneDrive\NareshIT\DSAIML\DataFiles\Visadataset.csv")


from sklearn.preprocessing import LabelEncoder
# Step 2 - save the package
le=LabelEncoder()
visa_df['education_of_employee']=le.fit_transform(visa_df['education_of_employee'])
visa_df
print(visa_df['education_of_employee'].values)

print(le.inverse_transform(visa_df['education_of_employee']))
# Out:
# [2 3 0 ... 3 3 0]
# ['High School' "Master's" "Bachelor's" ... "Master's" "Master's"
#  "Bachelor's"]

# %% [markdown]
# **np. where**
#
# - np.where is applicable only for binary
#
# - np.where will take 3 arguments
#
# - condition
#
# - True value
#
# - False value
#
# -

# %%
visa_df=pd.read_csv(r"C:\Users\Almannan\OneDrive\NareshIT\DSAIML\DataFiles\Visadataset.csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# $$scenario$
# - for example case status vlaye equal to certified replace with zero
# - otherwise replace with 1

# %%
visa_df['case_status']=np.where(visa_df['case_status']=='Certified',1,0)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# **One Hot Encoder**
#
# - One hot means, if one is ON then other one is OFF.
#
# - ON represents with 1, and OFF represents with 0
#
# - For example case status had two unique labels
#
#     - Denied
#
#     - Certified
#
#   - IF we apply One Hot encoder on cas status column, it will create two extra columns
#
#         - case_status_Denied
#
#         - case_status_Certified

# %% [markdown]
# |case_status|case_status_denied|case_status_certified|
# |-------|--|--|
# |Denied|1|0|
# |Certified|0|1|

# %% [markdown]
# **Advantages**
#
# - In Machine learning we have one important property is **Independent of variables**
#
# - Machine learning models expects variables are independent each other
#
# - One hot coder creating new columns, the new columns are **independent to each other**
#
# - Independent variable means both variables have **90 degrees phase shift**
#
# - 90 degrees phase shift also called as **perpendicular each other**
#
# - Perpendicular means **Orthogonal each other**

# %% [markdown]
# **Disadvantages**
#
# - One Hot encoder creates new columns equal to number of unique labels
#
# - If number of unique labels increased, will increase number of newcolumns
#
# - The more columns leads to more data
# -
# - the more data increases complexity
# -
# - complexisty increases more computation power required
# -
# - also time also increase
#
# - The entire process is named as **Curse of dimensionality**
# -

# %% [markdown]
# **pd.get_dummies**

# %% [markdown]
# - Read the data again
#
# - choose one column
#
# - apply pd.get_dummies

# %%
pd.get_dummies
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 pd.get_dummies
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
pd.get_dummies
# Out:
# <function pandas.core.reshape.encoding.get_dummies(data, prefix=None, prefix_sep: 'str | Iterable[str] | dict[str, str]' = '_', dummy_na: 'bool' = False, columns=None, sparse: 'bool' = False, drop_first: 'bool' = False, dtype: 'NpDtype | None' = None) -> 'DataFrame'>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visa_df=pd.read_csv(r"C:\Users\Almannan\OneDrive\NareshIT\DSAIML\DataFiles\Visadataset.csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
pd.get_dummies(visa_df['case_status'])
# Out:
#        Certified  Denied
# 0          False    True
# 1           True   False
# 2          False    True
# 3          False    True
# 4           True   False
# ...          ...     ...
# 25475       True   False
# 25476       True   False
# 25477       True   False
# 25478       True   False
# 25479       True   False
#
# [25480 rows x 2 columns]

# %%
pd.get_dummies(visa_df['region_of_employment'])
# Out:
#        Island  Midwest  Northeast  South   West
# 0       False    False      False  False   True
# 1       False    False       True  False  False
# 2       False    False      False  False   True
# 3       False    False      False  False   True
# 4       False    False      False   True  False
# ...       ...      ...        ...    ...    ...
# 25475   False    False      False   True  False
# 25476   False    False       True  False  False
# 25477   False    False      False   True  False
# 25478   False    False      False  False   True
# 25479   False     True      False  False  False
#
# [25480 rows x 5 columns]

# %%
pd.get_dummies(visa_df)
# Out:
#        no_of_employees  yr_of_estab  prevailing_wage  case_id_EZYV01  \
# 0                14513         2007         592.2029               1
# 1                 2412         2002       83425.6500               0
# 2                44444         2008      122996.8600               0
# 3                   98         1897       83434.0300               0
# 4                 1082         2005      149907.3900               0
# ...                ...          ...              ...             ...
# 25475             2601         2008       77092.5700               0
# 25476             3274         2006      279174.7900               0
# 25477             1121         1910      146298.8500               0
# 25478             1918         1887       86154.7700               0
# 25479             3195         1960       70876.9100               0
#
#        case_id_EZYV02  case_id_EZYV03  case_id_EZYV04  case_id_EZYV05  \
# ...

# %% [markdown]
# **Note**
#
# - Always drop the id column
# -

# %%
visa_df['case_id'].remove
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20428\798461446.py in ?()
# ----> 1 visa_df['case_id'].remove
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'remove'

# %%
pd.get_dummies(visa_df, dtype='int')
# Out:
#        no_of_employees  yr_of_estab  prevailing_wage  case_id_EZYV01  \
# 0                14513         2007         592.2029               1
# 1                 2412         2002       83425.6500               0
# 2                44444         2008      122996.8600               0
# 3                   98         1897       83434.0300               0
# 4                 1082         2005      149907.3900               0
# ...                ...          ...              ...             ...
# 25475             2601         2008       77092.5700               0
# 25476             3274         2006      279174.7900               0
# 25477             1121         1910      146298.8500               0
# 25478             1918         1887       86154.7700               0
# 25479             3195         1960       70876.9100               0
#
#        case_id_EZYV02  case_id_EZYV03  case_id_EZYV04  case_id_EZYV05  \
# ...

# %%
visa_df.drop('case_id', axis=1, inplace=True)

# %%
pd.get_dummies(visa_df)
# Out:
#        no_of_employees  yr_of_estab  prevailing_wage  continent_Africa  \
# 0                14513         2007         592.2029             False
# 1                 2412         2002       83425.6500             False
# 2                44444         2008      122996.8600             False
# 3                   98         1897       83434.0300             False
# 4                 1082         2005      149907.3900              True
# ...                ...          ...              ...               ...
# 25475             2601         2008       77092.5700             False
# 25476             3274         2006      279174.7900             False
# 25477             1121         1910      146298.8500             False
# 25478             1918         1887       86154.7700             False
# 25479             3195         1960       70876.9100             False
#
#        continent_Asia  continent_Europe  continent_North America  \
# ...

# %% [markdown]
# - Generally we will prefer Lable Encoder
#
# - - One hot encoder is useful lwheren categorical data has less unique labels/values
#   -
